# %%
from dotenv import load_dotenv
from agents import Agent, Runner, trace

# %%
load_dotenv(override=True)
# Out:
# True

# %%
agent = Agent(name="Beddtime Story Teller", instructions="You are a beddtime story teller.", model="gpt-4o-mini")

# %%
agent
# Out:
# Agent(name='Beddtime Story Teller', handoff_description=None, tools=[], mcp_servers=[], mcp_config={}, instructions='You are a beddtime story teller.', prompt=None, handoffs=[], model='gpt-4o-mini', model_settings=ModelSettings(temperature=None, top_p=None, frequency_penalty=None, presence_penalty=None, tool_choice=None, parallel_tool_calls=None, truncation=None, max_tokens=None, reasoning=None, verbosity=None, metadata=None, store=None, include_usage=None, response_include=None, top_logprobs=None, extra_query=None, extra_body=None, extra_headers=None, extra_args=None), input_guardrails=[], output_guardrails=[], output_type=None, hooks=None, tool_use_behavior='run_llm_again', reset_tool_choice=True)

# %%
with trace("Telling a beddtime story"):
    result = await Runner.run(agent, "Please tell me an Alice in Wonderland story.")
    print(result.final_output)
# Out:
# Once upon a time, in a quiet little town, there lived a curious girl named Alice. One sunny afternoon, while she was daydreaming in her favorite meadow, she spotted a peculiar white rabbit wearing a waistcoat and holding a pocket watch. He looked very distressed as he exclaimed, "Oh dear! Oh dear! I shall be too late!"
#
# Intrigued, Alice followed him down a large rabbit hole. With a twist and a turn, she found herself tumbling down into a whimsical world called Wonderland. When she landed, she looked around in amazement. The colors were brighter, the flowers seemed to dance, and the trees whispered secrets to one another.
#
# As she wandered through this enchanting land, Alice encountered a Cheshire Cat lounging on a tree branch. His smile was wide and mischievous. "Welcome to Wonderland!" he said, grinning. "Everyone's mad here, but that's what makes it fun. Where do you want to go?"
#
# "I’m not sure," Alice replied, a bit confused. "I just want to find my way back home."
#
# ...

# %%
#https://platform.openai.com/traces
